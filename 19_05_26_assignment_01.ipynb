# %%
#Question 01
# Student marksheet
name = input("Enter your name: ")
clas = input("Enter your class: ")
physics = float(input("Enter your physics marks: "))
chemistry = float(input("Enter your chemistry marks: "))
maths = float(input("Enter your maths marks: "))
english = float(input("Enter your english marks: "))
hindi = float(input("Enter your hindi marks: "))

# Calculate total and percentage
total = physics + chemistry + maths + english + hindi
percentage = (total / 500) * 100

# Print the marksheet
print("\nMarksheet")
print(f"Name: {name} \nClass: {clas} \nPercentage: {percentage:.2f}%")
# Out:
# Marksheet
# Name: akshat
# Class: 12th
# Percentage: 90.60%

# %%
#Question 02
s1 = "Heli"
s2 = "copter"

s = s1 + s2

#lower(), upper(), title(), swapcase(), capitalize(), casefold(), center(), count(),
#endswith(), find(), isalnum(), isdigit(), isnumeric(), isspace(), replace()
print(s)
print(s.lower())
print(s.upper())
print(s.title())
print(s.swapcase())
print(s.capitalize())
print(s.casefold())
print(s.center(60))
print(s.count("e"))
print(s.endswith("ter"))
print(s.find("e"))
print(s.isalpha())
print(s.isdigit())
print(s.isnumeric())
print(s.isspace())
print(s.replace("c", "C"))
# Out:
# Helicopter
# helicopter
# HELICOPTER
# Helicopter
# hELICOPTER
# Helicopter
# helicopter
#                          Helicopter
# 2
# True
# 1
# True
# False
# False
# False
# HeliCopter

# %%
#Question 03
x = 10
y = 5
print(x)

#Addition
y += x
print(y)

#Subtraction
y -= x
print(y)

#Multiplication
y *= x
print(y)

#Division
y /= x
print(y)
# Out:
# 10
# 15
# 5
# 50
# 5.0

# %%
#Question 04
print("Grade: ", end = "")
if 60 <= percentage <= 100:
    print("A")
elif 50 <= percentage < 60:
    print("B")
elif 40 <= percentage < 50:
    print("C")
elif 33 <= percentage < 40:
    print("D")
else:
    print("Fail")
# Out:
# Grade: A
